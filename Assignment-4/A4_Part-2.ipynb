# %%
import torch
import matplotlib.pyplot as plt
from utils import MELD, ModelTransformer, ModelGRU, train
# Out:
# /home/sid/anaconda3/lib/python3.11/site-packages/transformers/utils/generic.py:260: UserWarning: torch.utils._pytree._register_pytree_node is deprecated. Please use torch.utils._pytree.register_pytree_node instead.
#   torch.utils._pytree._register_pytree_node(

# %%
train_dataset = MELD('train_file.json', EFR=True)
val_dataset = MELD('val_file.json', EFR=True)

model3 = ModelTransformer()
model4 = ModelGRU()
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:88: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# ...
# 100%|██████████| 843/843 [00:01<00:00, 445.09it/s]

# %%
with torch.autocast(device_type='cuda', dtype=torch.float16):
    train_losses, val_losses, train_f1s, val_f1s = train(train_dataset, val_dataset, model3, num_epochs=7, task=2)
# Out:
# 100%|██████████| 6740/6740 [02:11<00:00, 51.17it/s]
# Validating
# 100%|██████████| 843/843 [00:11<00:00, 75.72it/s]
# Epoch 0 Train Loss : 0.5865272147940245 Val Loss : 0.5966193858768309 Train F1 : 0.08131025213088865 Val F1 : 0.07483071290145499
# 100%|██████████| 6740/6740 [02:10<00:00, 51.69it/s]
# Validating
# 100%|██████████| 843/843 [00:11<00:00, 74.85it/s]
# Epoch 1 Train Loss : 0.5804019341173441 Val Loss : 0.5920783672680634 Train F1 : 0.15191005065163984 Val F1 : 0.17374074169886802
# 100%|██████████| 6740/6740 [02:10<00:00, 51.77it/s]
# Validating
# 100%|██████████| 843/843 [00:11<00:00, 75.20it/s]
# Epoch 2 Train Loss : 0.5758790980637604 Val Loss : 0.5876999542665086 Train F1 : 0.2026869878730347 Val F1 : 0.23904162240688115
# 100%|██████████| 6740/6740 [02:08<00:00, 52.36it/s]
# Validating
# 100%|██████████| 843/843 [00:11<00:00, 74.14it/s]
# Epoch 3 Train Loss : 0.570519836039147 Val Loss : 0.5848845098861455 Train F1 : 0.23316294178251123 Val F1 : 0.27068033945862
# ...

# %%
plt.plot(train_losses)
plt.plot(val_losses)
plt.legend(['train loss', 'val_loss'])
plt.xticks(range(0, 7))
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.grid(True)
plt.show()

# %%
plt.plot(train_f1s)
plt.plot(val_f1s)
plt.legend(['train f1s', 'val f1s'])
plt.xticks(range(0, 7))
plt.xlabel("Epochs")
plt.ylabel("F1-Scores")
plt.grid(True)
plt.show()

# %%
with torch.autocast(device_type='cuda', dtype=torch.float16):
    train_losses, val_losses, train_f1s, val_f1s = train(train_dataset, val_dataset, model4, num_epochs=7, task=2)
# Out:
# 100%|██████████| 6740/6740 [02:02<00:00, 55.18it/s]
# Validating
# 100%|██████████| 843/843 [00:11<00:00, 74.78it/s]
# Epoch 0 Train Loss : 0.5500078047153151 Val Loss : 0.5417832409076985 Train F1 : 0.35286530664001403 Val F1 : 0.49440701464788583
# 100%|██████████| 6740/6740 [02:00<00:00, 55.93it/s]
# Validating
# 100%|██████████| 843/843 [00:11<00:00, 74.01it/s]
# Epoch 1 Train Loss : 0.5347347794725209 Val Loss : 0.5344803919076637 Train F1 : 0.4489316350008417 Val F1 : 0.5314218194239054
# 100%|██████████| 6740/6740 [02:01<00:00, 55.42it/s]
# Validating
# 100%|██████████| 843/843 [00:11<00:00, 73.92it/s]
# Epoch 2 Train Loss : 0.5254232774104491 Val Loss : 0.5302012387048873 Train F1 : 0.48406854017197487 Val F1 : 0.4910744592478338
# 100%|██████████| 6740/6740 [01:58<00:00, 56.68it/s]
# Validating
# 100%|██████████| 843/843 [00:11<00:00, 75.38it/s]
# Epoch 3 Train Loss : 0.5195138287163984 Val Loss : 0.526323865529057 Train F1 : 0.5041328528749474 Val F1 : 0.560076733265931
# ...

# %%
plt.plot(train_losses)
plt.plot(val_losses)
plt.legend(['train loss', 'val_loss'])
plt.xticks(range(0, 7))
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.grid(True)
plt.show()

# %%
plt.plot(train_f1s)
plt.plot(val_f1s)
plt.legend(['train f1s', 'val f1s'])
plt.xticks(range(0, 7))
plt.xlabel("Epochs")
plt.ylabel("F1-Scores")
plt.grid(True)
plt.show()
