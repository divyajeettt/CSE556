# %%
import torch
import matplotlib.pyplot as plt
from utils import MELD, ModelTransformer, ModelGRU, train

# %%
train_dataset = MELD('train_file.json', EFR=True)
val_dataset = MELD('val_file.json', EFR=True)

model3 = ModelTransformer(task=2)
model4 = ModelGRU(task=2)

# %%
with torch.autocast(device_type='cuda', dtype=torch.float16):
    train_losses, val_losses, train_f1s, val_f1s = train(train_dataset, val_dataset, model3, num_epochs=10, task=2)
# Out:
# 100%|██████████| 6740/6740 [02:47<00:00, 40.33it/s]
# Validating
# 100%|██████████| 843/843 [00:14<00:00, 57.93it/s]
# Epoch 0 Train Loss : 0.5112629821816962 Val Loss : 0.5056528148560621 Train F1 : 0.7694121560378036 Val F1 : 0.7817191866114866
# 100%|██████████| 6740/6740 [02:40<00:00, 42.02it/s]
# Validating
# 100%|██████████| 843/843 [00:13<00:00, 61.12it/s]
# Epoch 1 Train Loss : 0.507747503606608 Val Loss : 0.5022075134169306 Train F1 : 0.7728578415841054 Val F1 : 0.7860415856019907
# 100%|██████████| 6740/6740 [02:39<00:00, 42.19it/s]
# Validating
# 100%|██████████| 843/843 [00:13<00:00, 60.79it/s]
# Epoch 2 Train Loss : 0.5051666488721746 Val Loss : 0.5001298315372331 Train F1 : 0.7778853869071023 Val F1 : 0.7887401385698996
# 100%|██████████| 6740/6740 [02:48<00:00, 39.98it/s]
# Validating
# 100%|██████████| 843/843 [00:13<00:00, 61.19it/s]
# Epoch 3 Train Loss : 0.5029573632055998 Val Loss : 0.49826212430622513 Train F1 : 0.7806578881385613 Val F1 : 0.7901968030125877
# ...

# %%
plt.plot(train_losses)
plt.plot(val_losses)
plt.legend(['train loss', 'val_loss'])
plt.xticks(range(0, 10))
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.grid(True)
plt.show()

# %%
plt.plot(train_f1s)
plt.plot(val_f1s)
plt.legend(['train f1s', 'val f1s'])
plt.xticks(range(0, 10))
plt.xlabel("Epochs")
plt.ylabel("F1-Scores")
plt.grid(True)
plt.show()

# %%
with torch.autocast(device_type='cuda', dtype=torch.float16):
    train_losses, val_losses, train_f1s, val_f1s = train(train_dataset, val_dataset, model4, num_epochs=10, task=2)
# Out:
# 100%|██████████| 6740/6740 [02:33<00:00, 44.03it/s]
# Validating
# 100%|██████████| 843/843 [00:13<00:00, 61.67it/s]
# Epoch 0 Train Loss : 0.5124436962100448 Val Loss : 0.5067602521866948 Train F1 : 0.7690911062720857 Val F1 : 0.778548980117433
# 100%|██████████| 6740/6740 [02:25<00:00, 46.47it/s]
# Validating
# 100%|██████████| 843/843 [00:13<00:00, 61.96it/s]
# Epoch 1 Train Loss : 0.5104410660063478 Val Loss : 0.5040477916934171 Train F1 : 0.7691428759061265 Val F1 : 0.77888073261021
# 100%|██████████| 6740/6740 [02:25<00:00, 46.44it/s]
# Validating
# 100%|██████████| 843/843 [00:13<00:00, 60.54it/s]
# Epoch 2 Train Loss : 0.5075238246592286 Val Loss : 0.5040959443627444 Train F1 : 0.771601247028126 Val F1 : 0.7840823200402769
#  81%|████████  | 5434/6740 [01:57<00:26, 50.09it/s]

# %%
plt.plot(train_losses)
plt.plot(val_losses)
plt.legend(['train loss', 'val_loss'])
plt.xticks(range(0, 10))
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.grid(True)
plt.show()

# %%
plt.plot(train_f1s)
plt.plot(val_f1s)
plt.legend(['train f1s', 'val f1s'])
plt.xticks(range(0, 10))
plt.xlabel("Epochs")
plt.ylabel("F1-Scores")
plt.grid(True)
plt.show()
